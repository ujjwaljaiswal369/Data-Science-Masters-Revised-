# %% [markdown]
# # Python Operators

# %% [markdown]
# ## Python Operators
# - Logical
# - Equality
# - Comparision
# - Arithmetic

# %% [markdown]
# ### 3.1.1 Logical Operators
# In python following keywords are used for boolean operations -
#
# |Keywords | Meaning|
# |-|-|
# |**not**|unary negation|
# |**and**|conditional AND|
# |**or**|conditional OR|

# %% [markdown]
# ![LogicalOperators.png](attachment:9c4944e0-94a7-4b8b-9c1e-c378aac678b2.png)

# %% [markdown]
# **EXAMPLES**:

# %%
type(False)
# Out:
# bool

# %%
bool(1)
# Out:
# True

# %%
a = True
b = False

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not False
# Out:
# True

# %%
age = int(input('Enter the age'))

if age<18 or age>=35:
    print('Successful Execution')
# Out:
# Enter the age 16
# Successful Execution

# %% [markdown]
# ### Equality Operators
# Following operations are present in python for equlity check operation-
#
# |Operators|	Meaning|
# |-|-|
# |**is**|	**a is b** returns true if variable/identifiers a and b points to the same object|
# |**is not**|	**a is not b** returns true if variable/identifiers a and b points to the different object|
# |**==**|	**a == b** returns true if variable/identifiers a and b has same value|
# |**!=**|	**a != b** returns true if variable/identifiers a and b has different value|
#
# **EXAMPLES**:

# %%
a='krish'
b='krish1'
a==b
# Out:
# False

# %%
age = int(input('Enter the age'))

if age==18:
    print('You are in teenager age')
# Out:
# Enter the age 18
# You are in teenager age

# %%
## checking id's
a = 'krishna'
b = 'krishna'
print(id(a))
print(id(b))
# Out:
# 2276716787776
# 2276716787776

# %%
a is b
# Out:
# True

# %%
lst=[1,2,3]
lst1=[1,2,3]
print(id(lst))
print(id(lst1))
# Out:
# 2276711700160
# 2276713580224

# %%
lst is lst1
# Out:
# False

# %%
lst is not lst1
# Out:
# True

# %%
'krish'!='krish1'
# Out:
# True

# %% [markdown]
# ## comparison operators
#
# |Operation|	Meaning|
# |-|-|
# |<	|less than|
# |<=	|less than or equal to|
# |>|greater than|
# |>=|greater than or equal to|

# %%
marks = float(input('Enter the marks'))

if marks>=35:
    print('Pass')
    if marks>=50 or marks<=70:
        print('First')
elif marks<35:
    print('Fail')
# Out:
# Enter the marks 56
# Pass
# First

# %% [markdown]
# ## Arithmetic Operators
# |Operation|	Meaning|
# |-|-|
# |+|	addition|
# |-	|subtraction|
# |*	|multiplication|
# |/	|true division|
# |//	|integer division|
# |%	|the modulo operator|

# %%
24+24
# Out:
# 48

# %%
24-4
# Out:
# 20

# %%
24*4
# Out:
# 96

# %%
24/5
# Out:
# 4.8

# %%
24//5
# Out:
# 4

# %%
24%3
# Out:
# 0
